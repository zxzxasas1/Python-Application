# %%
# 遺漏值的處理方式



# 分成三個部分 : 

# 1. 辨識出四種遺漏值 , NaN , "" , " " , None

# 2. 將遺漏值轉換成 NaN

# 3. 用 pandas , numpy 或 python 內建函數來移除 NaN



# 1. 辨識遺漏值


# a. NaN : 

# 屬於數值型的類別，常常是計算產生，例如無窮大

# NaN 因此不能用 == 來辨識，要用各個模組的函數，像是 isna 之類


# b. "" : 

# 是空字串，但是還是算一種資料，屬於 string 

# 可以用 == "" 來偵測


# c. " " : 

# 是空白的字串，屬於 string

# 因為可能有多個空白，所以要搭配 strip() == "" 把空白拿掉確認沒有東西來辨識


# d. None : 

# 是 Python 的一種型別，就是 None 型別

# 可以直接用 == "None" 來偵測



# 2. 轉換成 NaN

# 因為多數模組有提供辨識 NaN 並移除的功能，因此可以轉換完後辨識並移除，例如 dropna()

# 轉換主要是用 replace 來進行



# 3. 移除 Nan

# 轉換成 NaN 之後用模組的辨識方式來

# 主要是用布林陣列或 List comprehension + if 來轉換其它遺漏值變成 NaN
